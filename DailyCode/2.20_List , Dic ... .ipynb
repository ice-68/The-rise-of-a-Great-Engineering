# %% [markdown]
# # ** Here is a markdown **

# %% [markdown]
# ##  1.1 Fundemental

# %%
from prompt_toolkit.shortcuts import clear

print("Hello world")

# %%
type(1+2)

# %%
type(True)

# %%
print("I miss you so much".lower())
"I miss you so much".count('o')

# %%
m1="I like you"
m1

# %%
m2=" I Do!"

# %%
m3=m1+' '+m2

# %% [markdown]
# ## 1.2 List

# %% [markdown]
# ### 1.2.0 some basic

# %%
meat=["meat","pork","chicken","roast duck"]

# %%
meat[0:3]

# %%
print(meat[0])
print(meat[2])
print(meat[3])

# %%
meat[-1]
meat.append('lamb')
meat.insert(1,'beaf')
meat

# %%
meat2=["a1","a2","a3"]

# %%
meat + meat2

# %%
meat3=[meat+meat2]
meat3

# %% [markdown]
# ### 1.2.1 Some algorithm

# %%
n = [2,3,12,4,5,78,10]

# %%
n.sort()
n

# %%
n.sort(reverse = True)
n #Once you sorted it , then the whole process will deal with the sorted list. !!!

# %%
n1=n[:]
n1
n2=n1.copy()
n2

# %% [markdown]
# ## 1.3 Dictionary

# %% [markdown]
# ### 1.3.0 Some basic operations

# %%
me={'name':'Tony','age':'20','height':'1.8m'}

# %%
me.keys(),me.values(),me.items()

# %%
me.update({'height':1.81})
me

# %% [markdown]
# ### 1.3.1 Some simple algorithm

# %%
mepro=me
memax=me.copy()

# %%
mepro.pop('name')

# %%
mepro

# %%
del mepro['age']

# %%
mepro

# %%
mepro.clear()

# %%
mepro
